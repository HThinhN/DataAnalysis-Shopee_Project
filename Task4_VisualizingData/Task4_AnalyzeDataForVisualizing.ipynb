# %% [markdown]
# ## **Task 4: Analyze data**
#
# <hr/>

# %%
# Import libraries
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### *1. Read preprocessing data from mongoDB Local*

# %%
client_Tlocal = MongoClient('mongodb://localhost:27017/')
db_Tlocal = client_Tlocal ['Task2_Database']
collection_Tlocal = db_Tlocal['Shopee_Full_Preprocessing_Data']
num_documents_Tlocal = collection_Tlocal.count_documents({})
print("Number of documents in the collection:", num_documents_Tlocal)
# Out:
# Number of documents in the collection: 549791

# %%
# Read preprocessing data from Thinh's MongoDB Local
def read_preprocessing_data(collection, num_documents):
    data_list = []
    total_documents = num_documents
    with tqdm(total=total_documents, desc='Getting Documents') as pbar:
        for document in collection.find({"crawl_id": {"$gte": 0, "$lt": total_documents}}):
            del document['_id']
            data_list.append(document)
            pbar.update(1)    

    df = pd.DataFrame(data_list)
    return df

# %%
df = read_preprocessing_data(collection_Tlocal, num_documents_Tlocal)
# Out:
# Getting Documents:   0%|          | 0/549791 [00:00<?, ?it/s]
# Getting Documents: 100%|██████████| 549791/549791 [01:11<00:00, 7677.78it/s]

# %%
df
# Out:
#              itemid    shopid  \
# 0       19393753758  40342563
# 1        4263018116  40342563
# 2       18484638101  40342563
# 3       23081308025  40342563
# 4       18040585153  40342563
# ...             ...       ...
# 549786   1258757931  75123404
# 549787   1258817062  75123404
# 549788   1267439667  75123404
# 549789   1267555891  75123404
# 549790   1267589839  75123404
#
#                                                      name  stock  sold  \
# 0       Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...    159   161
# 1       Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Đ...    240  3098
# 2       Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...    222   439
# 3       Áo Khoác Nam AVIANO Cao Cấp Chống Nước,Chống G...    216   387
# 4       Bộ Quần Áo Cho Bé Thiết Kế Kẻ Ô Cao Cấp Thời T...    317    26
# ...                                                   ...    ...   ...
# 549786  Vớ Cổ Trung Dành Cho Trẻ Em 12-14 Tuổi Thương ...     70     0
# 549787                 Vớ Trẻ Em Cổ Trung 3-5 Tuổi EBK170     75     0
# 549788  Vớ Không Cổ Dành Cho Nam Thương Hiệu ELLE EH L...     60     0
# 549789  Vớ Thể Thao Cổ Trung Dệt Xù Dành Cho Nam Thươn...     79     0
# 549790  Vớ Thể Thao Cổ Ngắn Dệt Xù Dành Cho Nam Thương...     20     0
#
#         historical_sold  liked_count  cmt_count item_status     price  ...  \
# 0                   163           41         40      normal  285000.0  ...
# 1                 39098         5112      12119      normal  185000.0  ...
# 2                   462           77        136      normal  185000.0  ...
# 3                   397          107        118      normal  229000.0  ...
# 4                   227           35         87      normal   99000.0  ...
# ...                 ...          ...        ...         ...       ...  ...
# 549786                3            0          1      normal   21000.0  ...
# 549787               14            1          1      normal   25000.0  ...
# 549788               22            2          1      normal   50000.0  ...
# 549789               11            4          4      normal   70000.0  ...
# 549790               35            3          8      normal   70000.0  ...
#
#         global_sold_count  flash_sale_stock           crawl_time  crawl_id  \
# 0                     163               159  2023-11-02 12:00:00         0
# 1                   39098               240  2023-11-02 12:00:00         1
# 2                     462               222  2023-11-02 12:00:00         2
# 3                     397               216  2023-11-02 12:00:00         3
# 4                     227                 0  2023-11-02 12:00:00         4
# ...                   ...               ...                  ...       ...
# 549786                  3                 0  2023-12-05 23:20:53    549786
# 549787                 14                 0  2023-12-05 23:20:53    549787
# 549788                 22                 0  2023-12-05 23:20:53    549788
# 549789                 11                 0  2023-12-05 23:20:53    549789
# 549790                 35                 0  2023-12-05 23:20:53    549790
#
#              color             size  rating_star  \
# 0        ĐEN, TIÊU  [M, L, XL, XXL]     4.925000
# 1              Ghi  [M, L, XL, XXL]     4.845551
# 2       ĐEN, TRẮNG  [M, L, XL, XXL]     4.897059
# 3              ĐEN  [M, L, XL, XXL]     4.872881
# 4              Nâu  [2, 3, 4, 5, 6]     4.875000
# ...            ...              ...          ...
# 549786        XANH        [No size]     5.000000
# 549787        XANH        [No size]     5.000000
# 549788         ĐEN        [No size]     5.000000
# 549789    ĐEN, XÁM        [No size]     5.000000
# 549790         ĐEN        [No size]     5.000000
#
#                              rating_count  rcount_with_image  \
# 0                    [40, 0, 0, 0, 3, 37]                 16
# 1       [12120, 119, 86, 265, 616, 11034]               5409
# 2                  [136, 2, 1, 0, 3, 130]                 58
# 3                  [118, 1, 2, 1, 3, 111]                 45
# 4                    [88, 1, 0, 2, 3, 82]                 45
# ...                                   ...                ...
# 549786                 [1, 0, 0, 0, 0, 1]                  0
# 549787                 [1, 0, 0, 0, 0, 1]                  0
# 549788                 [1, 0, 0, 0, 0, 1]                  0
# 549789                 [4, 0, 0, 0, 0, 4]                  0
# 549790                 [8, 0, 0, 0, 0, 8]                  1
#
#        rcount_with_context
# 0                       21
# 1                     6928
# 2                       74
# 3                       59
# 4                       51
# ...                    ...
# 549786                   0
# 549787                   0
# 549788                   1
# 549789                   2
# 549790                   1
#
# [549791 rows x 31 columns]

# %% [markdown]
# ### *2. Read raw data from mongoDB Atlas*

# %%
# MONGODB_URI = "mongodb+srv://MasterMind:MasterMind@productpage.nj9srv4.mongodb.net/"
# client_SAtlas = MongoClient(MONGODB_URI, server_api=ServerApi('1'))

# # Send a ping to confirm a successful connection
# try:
#     client_SAtlas.admin.command('ping')
#     print("Pinged your deployment. You successfully connected to MongoDB!")
# except Exception as e:
#     print(e)
# db_SAtlas = client_SAtlas.get_database('product_pages')
# records = db_SAtlas.items

# %% [markdown]
# #### *2.1. Preprocessing data in Son MongoDB Atlas*

# %%
# cursor = records.find({})

# %%
# data_list = []
# for document in cursor:
#             del document['_id']
#             data_list.append(document)
            
# raw_df = pd.DataFrame(data_list)

# %%
# json_content = pd.DataFrame(raw_df['items'].apply(pd.Series))
# item_infor = pd.DataFrame(json_content['item'].apply(pd.Series))
# description_df = pd.DataFrame(item_infor[['item_id','shop_id', 'title', 'description']])
# description_df.to_csv('sample.csv',index=False,header=True,encoding="utf-8-sig")

# %% [markdown]
# ### *3. Analyze keyword from title of products*

# %%
raw_df = df.copy()
raw_df
# Out:
#              itemid    shopid  \
# 0       19393753758  40342563
# 1        4263018116  40342563
# 2       18484638101  40342563
# 3       23081308025  40342563
# 4       18040585153  40342563
# ...             ...       ...
# 549786   1258757931  75123404
# 549787   1258817062  75123404
# 549788   1267439667  75123404
# 549789   1267555891  75123404
# 549790   1267589839  75123404
#
#                                                      name  stock  sold  \
# 0       Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...    159   161
# 1       Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Đ...    240  3098
# 2       Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...    222   439
# 3       Áo Khoác Nam AVIANO Cao Cấp Chống Nước,Chống G...    216   387
# 4       Bộ Quần Áo Cho Bé Thiết Kế Kẻ Ô Cao Cấp Thời T...    317    26
# ...                                                   ...    ...   ...
# 549786  Vớ Cổ Trung Dành Cho Trẻ Em 12-14 Tuổi Thương ...     70     0
# 549787                 Vớ Trẻ Em Cổ Trung 3-5 Tuổi EBK170     75     0
# 549788  Vớ Không Cổ Dành Cho Nam Thương Hiệu ELLE EH L...     60     0
# 549789  Vớ Thể Thao Cổ Trung Dệt Xù Dành Cho Nam Thươn...     79     0
# 549790  Vớ Thể Thao Cổ Ngắn Dệt Xù Dành Cho Nam Thương...     20     0
#
#         historical_sold  liked_count  cmt_count item_status     price  ...  \
# 0                   163           41         40      normal  285000.0  ...
# 1                 39098         5112      12119      normal  185000.0  ...
# 2                   462           77        136      normal  185000.0  ...
# 3                   397          107        118      normal  229000.0  ...
# 4                   227           35         87      normal   99000.0  ...
# ...                 ...          ...        ...         ...       ...  ...
# 549786                3            0          1      normal   21000.0  ...
# 549787               14            1          1      normal   25000.0  ...
# 549788               22            2          1      normal   50000.0  ...
# 549789               11            4          4      normal   70000.0  ...
# 549790               35            3          8      normal   70000.0  ...
#
#         global_sold_count  flash_sale_stock           crawl_time  crawl_id  \
# 0                     163               159  2023-11-02 12:00:00         0
# 1                   39098               240  2023-11-02 12:00:00         1
# 2                     462               222  2023-11-02 12:00:00         2
# 3                     397               216  2023-11-02 12:00:00         3
# 4                     227                 0  2023-11-02 12:00:00         4
# ...                   ...               ...                  ...       ...
# 549786                  3                 0  2023-12-05 23:20:53    549786
# 549787                 14                 0  2023-12-05 23:20:53    549787
# 549788                 22                 0  2023-12-05 23:20:53    549788
# 549789                 11                 0  2023-12-05 23:20:53    549789
# 549790                 35                 0  2023-12-05 23:20:53    549790
#
#              color             size  rating_star  \
# 0        ĐEN, TIÊU  [M, L, XL, XXL]     4.925000
# 1              Ghi  [M, L, XL, XXL]     4.845551
# 2       ĐEN, TRẮNG  [M, L, XL, XXL]     4.897059
# 3              ĐEN  [M, L, XL, XXL]     4.872881
# 4              Nâu  [2, 3, 4, 5, 6]     4.875000
# ...            ...              ...          ...
# 549786        XANH        [No size]     5.000000
# 549787        XANH        [No size]     5.000000
# 549788         ĐEN        [No size]     5.000000
# 549789    ĐEN, XÁM        [No size]     5.000000
# 549790         ĐEN        [No size]     5.000000
#
#                              rating_count  rcount_with_image  \
# 0                    [40, 0, 0, 0, 3, 37]                 16
# 1       [12120, 119, 86, 265, 616, 11034]               5409
# 2                  [136, 2, 1, 0, 3, 130]                 58
# 3                  [118, 1, 2, 1, 3, 111]                 45
# 4                    [88, 1, 0, 2, 3, 82]                 45
# ...                                   ...                ...
# 549786                 [1, 0, 0, 0, 0, 1]                  0
# 549787                 [1, 0, 0, 0, 0, 1]                  0
# 549788                 [1, 0, 0, 0, 0, 1]                  0
# 549789                 [4, 0, 0, 0, 0, 4]                  0
# 549790                 [8, 0, 0, 0, 0, 8]                  1
#
#        rcount_with_context
# 0                       21
# 1                     6928
# 2                       74
# 3                       59
# 4                       51
# ...                    ...
# 549786                   0
# 549787                   0
# 549788                   1
# 549789                   2
# 549790                   1
#
# [549791 rows x 31 columns]

# %% [markdown]
# #### 3.1. Filtering top 50 products from top shop mall and normal shop:

# %%
top_shopee_mall_id = [40342563, 225909574, 68613764, 24710134, 127217331, 60297616, 111639450,\
                      317477677, 201774917, 59596762, 168678363, 92937520, 68988783, 263713672,\
                      38038824, 277366270, 70677296, 1620236, 17893078, 31522834, 16649961,\
                      296132807, 257412160]
normal_shop_id = [999122826, 952153869, 47401874, 80968732,744060250,127049276,324062232,205125399,\
                  427693365, 360972139, 168195778, 913496573, 299977840, 183199642, 416018485,\
                  264542552, 78461361, 329002439, 108136164, 75123404]

# %%
raw_df = raw_df[['itemid','shopid','name','sold','price','rating_star']]
raw_df
# Out:
#              itemid    shopid  \
# 0       19393753758  40342563
# 1        4263018116  40342563
# 2       18484638101  40342563
# 3       23081308025  40342563
# 4       18040585153  40342563
# ...             ...       ...
# 549786   1258757931  75123404
# 549787   1258817062  75123404
# 549788   1267439667  75123404
# 549789   1267555891  75123404
# 549790   1267589839  75123404
#
#                                                      name  sold     price  \
# 0       Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...   161  285000.0
# 1       Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Đ...  3098  185000.0
# 2       Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...   439  185000.0
# 3       Áo Khoác Nam AVIANO Cao Cấp Chống Nước,Chống G...   387  229000.0
# 4       Bộ Quần Áo Cho Bé Thiết Kế Kẻ Ô Cao Cấp Thời T...    26   99000.0
# ...                                                   ...   ...       ...
# 549786  Vớ Cổ Trung Dành Cho Trẻ Em 12-14 Tuổi Thương ...     0   21000.0
# 549787                 Vớ Trẻ Em Cổ Trung 3-5 Tuổi EBK170     0   25000.0
# 549788  Vớ Không Cổ Dành Cho Nam Thương Hiệu ELLE EH L...     0   50000.0
# 549789  Vớ Thể Thao Cổ Trung Dệt Xù Dành Cho Nam Thươn...     0   70000.0
# 549790  Vớ Thể Thao Cổ Ngắn Dệt Xù Dành Cho Nam Thương...     0   70000.0
#
#         rating_star
# 0          4.925000
# 1          4.845551
# 2          4.897059
# 3          4.872881
# 4          4.875000
# ...             ...
# 549786     5.000000
# 549787     5.000000
# 549788     5.000000
# 549789     5.000000
# 549790     5.000000
#
# [549791 rows x 6 columns]

# %%
# Remove duplicated data and keep the last value
analyzed_df = raw_df.drop_duplicates(subset='itemid', keep='last')
analyzed_df.reset_index(drop=True, inplace=True)
analyzed_df
# Out:
#            itemid     shopid  \
# 0     16985661061  317477677
# 1      6944158731   92937520
# 2     15494176620   92937520
# 3     14498861181   92937520
# 4     23680547799  296132807
# ...           ...        ...
# 9307   1258757931   75123404
# 9308   1258817062   75123404
# 9309   1267439667   75123404
# 9310   1267555891   75123404
# 9311   1267589839   75123404
#
#                                                    name  sold      price  \
# 0                        Quần Jean LEVENTS Crayon/ Blue     5   413000.0
# 1       Áo sơ mi dài tay nam Owen Regularfit- AR20728DT    45   598000.0
# 2           OWEN - Quần Boxer nam màu Xanh - QLBR221094     1   120000.0
# 3     OWEN - Áo sơ mi Nam dài tay Slim Fit màu Navy ...     0  1200000.0
# 4     Quần Đùi Nam SAIGONESE Short Thun Phối Line Th...     4   119000.0
# ...                                                 ...   ...        ...
# 9307  Vớ Cổ Trung Dành Cho Trẻ Em 12-14 Tuổi Thương ...     0    21000.0
# 9308                 Vớ Trẻ Em Cổ Trung 3-5 Tuổi EBK170     0    25000.0
# 9309  Vớ Không Cổ Dành Cho Nam Thương Hiệu ELLE EH L...     0    50000.0
# 9310  Vớ Thể Thao Cổ Trung Dệt Xù Dành Cho Nam Thươn...     0    70000.0
# 9311  Vớ Thể Thao Cổ Ngắn Dệt Xù Dành Cho Nam Thương...     0    70000.0
#
#       rating_star
# 0        4.962264
# 1        4.881356
# 2        0.000000
# 3        0.000000
# 4        5.000000
# ...           ...
# 9307     5.000000
# 9308     5.000000
# 9309     5.000000
# 9310     5.000000
# 9311     5.000000
#
# [9312 rows x 6 columns]

# %%
# SM: Shop Mall
# NM: Normal Shop
top_50_items_SM_df = pd.DataFrame(columns=['shopid','name'])
top_50_items_NM_df = pd.DataFrame(columns=['shopid','name'])

# %%
# Get 50 products from each Shop Mall (SM)
for i in tqdm(range(0,len(top_shopee_mall_id))):
    shopid = top_shopee_mall_id[i]
    all_items = analyzed_df[analyzed_df['shopid'] == str(shopid)][['name','sold']].sort_values(by='sold',ascending=False)
    try:
        top_50_SM_items = list(all_items['name'].iloc[:50])
    except:
        top_50_SM_items = list(all_items['name'])
    shopid_list = [shopid] * len(top_50_SM_items)
    result = pd.DataFrame({'shopid': shopid_list, 'name': top_50_SM_items})
    top_50_items_SM_df = pd.concat([top_50_items_SM_df, result], ignore_index=True)
# Out:
#  48%|████▊     | 11/23 [00:00<00:00, 108.89it/s]
# 100%|██████████| 23/23 [00:00<00:00, 110.12it/s]

# %%
top_50_items_SM_df
# Out:
#          shopid                                               name
# 0      40342563  Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Đ...
# 1      40342563  Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...
# 2      40342563        COMBO 5 đôi tất nam Trơn VICERO Kháng khuẩn
# 3      40342563  Áo Nỉ Nam Thời Trang Trẻ Trung Chất Vải Co Dãn...
# 4      40342563  Bộ Thể Thao Nam 3 Sọc Mùa Đông Da Cá Chéo Thời...
# ...         ...                                                ...
# 1133  257412160  Áo thun nam cổ tròn, T-shirt nam đen in AREMI,...
# 1134  257412160  Áo polo nam tay ngắn cổ trụ AREMI thiết kế độc...
# 1135  257412160  Áo thun nam tay ngắn cổ tròn thiết kế AREMI ch...
# 1136  257412160  Áo polo nam cổ trụ tay ngắn AREMI thiết kế đơn...
# 1137  257412160  Áo polo nam tay ngắn cổ trụ thiết kế AREMI chấ...
#
# [1138 rows x 2 columns]

# %%
# Get 50 products from each Normal Shop (NM)
for i in tqdm(range(0,len(normal_shop_id))):
    shopid = normal_shop_id[i]
    all_items = analyzed_df[analyzed_df['shopid'] == str(shopid)][['name','sold']].sort_values(by='sold',ascending=False)
    try:
        top_50_NM_items = list(all_items['name'].iloc[:50])
    except:
        top_50_NM_items = list(all_items['name'])
    shopid_list = [shopid] * len(top_50_NM_items)
    result = pd.DataFrame({'shopid': shopid_list, 'name': top_50_NM_items})
    top_50_items_NM_df = pd.concat([top_50_items_NM_df, result], ignore_index=True)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 103.53it/s]

# %%
top_50_items_NM_df
# Out:
#         shopid                                               name
# 0    999122826  Hàng Có Sẵn! Hàng Có Sẵn!Phong cách dân tộc mù...
# 1    999122826  Hàng Có Sẵn! Hàng Có Sẵn!Shaoye Quần Váy Dài D...
# 2    999122826  Hàng sẵn sàng!Nam giới kích thước lớn phong cá...
# 3    999122826  Hàng Có Sẵn!Quần Giả Váy Lưng Thun Ống Rộng Th...
# 4    999122826  Hàng Có Sẵn!Set Đồ Thể Thao Phối Áo Ba Lỗ Vải ...
# ..         ...                                                ...
# 905   75123404  Vớ Thể Thao Cổ Trung Dành Cho Nam Thương Hiệu ...
# 906   75123404  Vớ Trẻ Em Cổ Ngắn 2-3 Tuổi Thương Hiệu ELLE EB...
# 907   75123404  Set 4 Đôi Vớ Công Sở Cổ Trung Dành Cho Nam Thư...
# 908   75123404  Vớ Công Sở Cổ Trung Dành Cho Nam Thương Hiệu E...
# 909   75123404  Vớ Không Cổ Dành Cho Nam Thương Hiệu ELLE EH L...
#
# [910 rows x 2 columns]

# %% [markdown]
# #### 3.2. Tokenize k-word in each products:

# %%
def tokenize_k_word(documents, k, stopwords):
    preprocessed_documents = [doc.lower() for doc in documents]
    vectorizer = CountVectorizer(ngram_range= (k,k), stop_words= stopwords)
    word_counts = vectorizer.fit_transform(preprocessed_documents)
    words = vectorizer.get_feature_names_out()
    word_occurrences = word_counts.toarray().sum(axis=0)
    word_count_dict = dict(zip(words, word_occurrences))
    Word = []
    Count = []
    for word, count in word_count_dict.items():
        Word.append(word)
        Count.append(count)
    return Word, Count

# %% [markdown]
# #### TOP SHOP MALL

# %% [markdown]
# ##### **k = 1**

# %%
# documents = list(top_50_items_SM_df['name'])
# stopwords = ['nam', 'áo', 'quần', 'vải']
# # stopwords = None
# Word, Count = tokenize_k_word(documents, 1, stopwords)
# infor_1w_df = pd.DataFrame({'Word': Word, 'Count': Count})
# infor_best_1w_df = infor_1w_df.sort_values(by='Count',ascending=False)[:50]
# infor_best_1w_df.reset_index(drop=True, inplace=True)
# infor_best_1w_df

# %% [markdown]
# Ban đầu, khi chạy dòng lệnh trên thì nhóm em thấy có rất nhiều từ mang tính thời trang (Tức là những từ gần như là phải có trong mọi sản phẩm), thông tin này không hề có giá trị nên nhóm em đã đưa nó vào nhóm stopwords, tức là những từ ngữ không ý nghĩa

# %% [markdown]
# ##### **k = 2**

# %%
# # documents = list(top_50_items_SM_df['name'])
# documents = list(analyzed_df['name'])
# # stopwords = ['nam', 'áo', 'quần', 'vải']
# stopwords = None
# Word, Count = tokenize_k_word(documents, 2, stopwords)
# infor_2w_df = pd.DataFrame({'Word': Word, 'Count': Count})
# infor_best_2w_df = infor_2w_df.sort_values(by='Count',ascending=False)[:50]
# infor_best_2w_df.reset_index(drop=True, inplace=True)
# infor_best_2w_df

# %%
# documents = list(top_50_items_SM_df['name'])
# # stopwords = ['nam', 'áo', 'quần', 'vải']
# stopwords = None
# Word, Count = tokenize_k_word(documents, 3, stopwords)
# infor_3w_df = pd.DataFrame({'Word': Word, 'Count': Count})
# infor_best_3w_df = infor_3w_df.sort_values(by='Count',ascending=False)[:50]
# infor_best_3w_df.reset_index(drop=True, inplace=True)
# infor_best_3w_df

# %% [markdown]
# # ...

# %% [markdown]
# #### NORMAL SHOP

# %%
# documents = list(top_50_items_NM_df['name'])
# # stopwords = ['nam', 'áo', 'quần', 'vải']
# stopwords = None
# Word, Count = tokenize_k_word(documents, 1, stopwords)
# infor_1w_df = pd.DataFrame({'Word': Word, 'Count': Count})
# infor_best_1w_df = infor_1w_df.sort_values(by='Count',ascending=False)[:50]
# infor_best_1w_df.reset_index(drop=True, inplace=True)
# infor_best_1w_df

# %%
# documents = list(top_50_items_NM_df['name'])
# # stopwords = ['nam', 'áo', 'quần', 'vải']
# stopwords = None
# Word, Count = tokenize_k_word(documents, 2, stopwords)
# infor_2w_df = pd.DataFrame({'Word': Word, 'Count': Count})
# infor_best_2w_df = infor_2w_df.sort_values(by='Count',ascending=False)[:50]
# infor_best_2w_df.reset_index(drop=True, inplace=True)
# infor_best_2w_df

# %% [markdown]
# ### 3.3 Form dataframe top popular keyword

# %%
analyzed_df
# Out:
#            itemid     shopid  \
# 0     16985661061  317477677
# 1      6944158731   92937520
# 2     15494176620   92937520
# 3     14498861181   92937520
# 4     23680547799  296132807
# ...           ...        ...
# 9307   1258757931   75123404
# 9308   1258817062   75123404
# 9309   1267439667   75123404
# 9310   1267555891   75123404
# 9311   1267589839   75123404
#
#                                                    name  sold      price  \
# 0                        Quần Jean LEVENTS Crayon/ Blue     5   413000.0
# 1       Áo sơ mi dài tay nam Owen Regularfit- AR20728DT    45   598000.0
# 2           OWEN - Quần Boxer nam màu Xanh - QLBR221094     1   120000.0
# 3     OWEN - Áo sơ mi Nam dài tay Slim Fit màu Navy ...     0  1200000.0
# 4     Quần Đùi Nam SAIGONESE Short Thun Phối Line Th...     4   119000.0
# ...                                                 ...   ...        ...
# 9307  Vớ Cổ Trung Dành Cho Trẻ Em 12-14 Tuổi Thương ...     0    21000.0
# 9308                 Vớ Trẻ Em Cổ Trung 3-5 Tuổi EBK170     0    25000.0
# 9309  Vớ Không Cổ Dành Cho Nam Thương Hiệu ELLE EH L...     0    50000.0
# 9310  Vớ Thể Thao Cổ Trung Dệt Xù Dành Cho Nam Thươn...     0    70000.0
# 9311  Vớ Thể Thao Cổ Ngắn Dệt Xù Dành Cho Nam Thương...     0    70000.0
#
#       rating_star
# 0        4.962264
# 1        4.881356
# 2        0.000000
# 3        0.000000
# 4        5.000000
# ...           ...
# 9307     5.000000
# 9308     5.000000
# 9309     5.000000
# 9310     5.000000
# 9311     5.000000
#
# [9312 rows x 6 columns]

# %%
analyzed_df.loc[:, 'approximate_revenue'] = analyzed_df['sold'] * analyzed_df['price']
analyzed_df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21720\1539943042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analyzed_df.loc[:, 'approximate_revenue'] = analyzed_df['sold'] * analyzed_df['price']
#            itemid     shopid  \
# 0     16985661061  317477677
# 1      6944158731   92937520
# 2     15494176620   92937520
# 3     14498861181   92937520
# 4     23680547799  296132807
# ...           ...        ...
# 9307   1258757931   75123404
# 9308   1258817062   75123404
# 9309   1267439667   75123404
# 9310   1267555891   75123404
# 9311   1267589839   75123404
#
#                                                    name  sold      price  \
# 0                        Quần Jean LEVENTS Crayon/ Blue     5   413000.0
# 1       Áo sơ mi dài tay nam Owen Regularfit- AR20728DT    45   598000.0
# 2           OWEN - Quần Boxer nam màu Xanh - QLBR221094     1   120000.0
# 3     OWEN - Áo sơ mi Nam dài tay Slim Fit màu Navy ...     0  1200000.0
# 4     Quần Đùi Nam SAIGONESE Short Thun Phối Line Th...     4   119000.0
# ...                                                 ...   ...        ...
# 9307  Vớ Cổ Trung Dành Cho Trẻ Em 12-14 Tuổi Thương ...     0    21000.0
# 9308                 Vớ Trẻ Em Cổ Trung 3-5 Tuổi EBK170     0    25000.0
# 9309  Vớ Không Cổ Dành Cho Nam Thương Hiệu ELLE EH L...     0    50000.0
# 9310  Vớ Thể Thao Cổ Trung Dệt Xù Dành Cho Nam Thươn...     0    70000.0
# 9311  Vớ Thể Thao Cổ Ngắn Dệt Xù Dành Cho Nam Thương...     0    70000.0
#
#       rating_star  approximate_revenue
# 0        4.962264            2065000.0
# 1        4.881356           26910000.0
# 2        0.000000             120000.0
# 3        0.000000                  0.0
# 4        5.000000             476000.0
# ...           ...                  ...
# 9307     5.000000                  0.0
# 9308     5.000000                  0.0
# 9309     5.000000                  0.0
# 9310     5.000000                  0.0
# 9311     5.000000                  0.0
#
# [9312 rows x 7 columns]

# %%
test_df = analyzed_df[analyzed_df['shopid'] == '40342563']
search_string = 'cao cấp'
# Hiển thị các hàng có chứa chuỗi cụ thể
t = test_df.sort_values(by='sold',ascending=False).reset_index(drop=True)
t.reset_index(inplace=True)
t
# Out:
#      index       itemid    shopid  \
# 0        0   4263018116  40342563
# 1        1  18484638101  40342563
# 2        2   1679232406  40342563
# 3        3   4649597158  40342563
# 4        4  19749576955  40342563
# ..     ...          ...       ...
# 186    186  16425906633  40342563
# 187    187  13681855901  40342563
# 188    188  18588438649  40342563
# 189    189  12073629517  40342563
# 190    190  22630455837  40342563
#
#                                                   name  sold     price  \
# 0    Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Đ...  6595  185000.0
# 1    Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...  3912  195000.0
# 2          COMBO 5 đôi tất nam Trơn VICERO Kháng khuẩn  2731   60000.0
# 3    Áo Nỉ Nam Thời Trang Trẻ Trung Chất Vải Co Dãn...  2704  129000.0
# 4    Bộ Thể Thao Nam 3 Sọc Mùa Đông Da Cá Chéo Thời...  1833  275000.0
# ..                                                 ...   ...       ...
# 186  Áo Polo AVIANO Tay Ngắn 2 Màu Xanh Trắng Bo Cổ...     0  139000.0
# 187  Áo Polo Ngắn Tay 5 Màu Thời Trang Cao Cấp Thiế...     0   99000.0
# 188  Áo Polo Nam AVIANO Chất Liệu Co Giãn Thấm Hút ...     0  139000.0
# 189  Bộ Đồ Nam AVIANO, Set Đồ Nam Polo Tay Ngắn Mix...     0  199000.0
# 190  Bộ Quần Áo Nam Mùa Hè AVIANO, Bộ Đồ Nam Cộc Ta...     0  169000.0
#
#      rating_star  approximate_revenue
# 0       4.846812         1.220075e+09
# 1       4.847720         7.628400e+08
# 2       4.791030         1.638600e+08
# 3       4.882612         3.488160e+08
# 4       4.874379         5.040750e+08
# ..           ...                  ...
# 186     4.910995         0.000000e+00
# 187     4.979522         0.000000e+00
# 188     5.000000         0.000000e+00
# 189     4.924906         0.000000e+00
# 190     4.857143         0.000000e+00
#
# [191 rows x 8 columns]

# %%
documents = list(analyzed_df['name']) 
stopwords = None
Word, Count = tokenize_k_word(documents, 1, stopwords)
infor_1w_df = pd.DataFrame({'Word': Word, 'Count': Count})
infor_best_1w_df = infor_1w_df.sort_values(by='Count',ascending=False)[:900]
infor_best_1w_df.reset_index(drop=True, inplace=True)
infor_best_1w_df
# Out:
#        Word  Count
# 0       nam   6529
# 1        áo   5535
# 2      quần   2824
# 3       tay   2588
# 4      hàng   2382
# ..      ...    ...
# 895  nguyên     10
# 896    2101     10
# 897   ngoại     10
# 898      ma     10
# 899   hr233     10
#
# [900 rows x 2 columns]

# %%
top_shopee_mall_id = list(map(str, top_shopee_mall_id))
normal_shop_id = list(map(str, normal_shop_id))
list_total_sold = []
list_rating_average = []
list_arevenue = []
list_n_shop_mall = []
list_sm_ra = []
list_sm_sold = []
list_sm_arevenue = []
list_n_normal_shop = []
list_ns_ra = []
list_ns_sold = []
list_ns_arevenue = []
for keyword in infor_best_1w_df['Word']: 
    # Kiểm tra xem các giá trị trong cột 'Column' có chứa chuỗi cụ thể hay không
    contains_search_string = analyzed_df['name'].str.lower().str.contains(keyword)
    total_sold = analyzed_df[contains_search_string]['sold'].sum()
    list_total_sold.append(total_sold)
    rating_average = analyzed_df[contains_search_string]['rating_star'].mean()
    list_rating_average.append(rating_average)
    arevenue = analyzed_df[contains_search_string]['approximate_revenue'].sum()
    list_arevenue.append(arevenue)
    # SM
    n_shop_mall = analyzed_df[contains_search_string]['shopid'].isin(top_shopee_mall_id).sum()
    list_n_shop_mall.append(n_shop_mall)
    sm_ra = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(top_shopee_mall_id)]['rating_star'].mean()
    list_sm_ra.append(sm_ra)
    sm_sold = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(top_shopee_mall_id)]['sold'].sum()
    list_sm_sold.append(sm_sold)
    sm_arevenue = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(top_shopee_mall_id)]['approximate_revenue'].sum()
    list_sm_arevenue.append(sm_arevenue)
    # NS
    n_normal_shop = analyzed_df[contains_search_string]['shopid'].isin(normal_shop_id).sum()
    list_n_normal_shop.append(n_normal_shop)
    ns_ra = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(normal_shop_id)]['rating_star'].mean()
    list_ns_ra.append(ns_ra)
    ns_sold = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(normal_shop_id)]['sold'].sum()
    list_ns_sold.append(ns_sold)
    ns_arevenue = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(normal_shop_id)]['approximate_revenue'].sum()
    list_ns_arevenue.append(ns_arevenue)

# %%
infor_1w_df = infor_best_1w_df.copy()
infor_1w_df['Total Sold'] = list_total_sold
infor_1w_df['Approximate Revenue'] = list_arevenue
infor_1w_df['Rating Average'] = list_rating_average
infor_1w_df['Shopee Mall'] = list_n_shop_mall
infor_1w_df['SM Rating Average'] = list_sm_ra
infor_1w_df['SM Approximate Revenue'] = list_sm_arevenue
infor_1w_df['SM Sold'] = list_sm_sold
infor_1w_df['Normal Shop'] = list_n_normal_shop
infor_1w_df['NS Rating Average'] = list_ns_ra
infor_1w_df['NS Approximate Revenue'] = list_ns_arevenue
infor_1w_df['NS Sold'] = list_ns_sold
infor_1w_df['Count'] = infor_1w_df['Shopee Mall'] + infor_1w_df['Normal Shop']

# %%
infor_1w_df = infor_1w_df[infor_1w_df['Count'] != 0]
len(infor_1w_df)
# Out:
# 900

# %%
stopwords_1w = ["áo","quần","hàng","trang","thời","cao","chất","có","cho","sơ", "mi", "sẵn", "dài", "cấp", "cách", \
                "phong","dáng", "khoác", "quốc", "hàn", "thể", "thao", "short", "co", "hình", "trung","ng","ch","th","hà",\
                     "ca", "to", "anh", "or", "cá", "ong", "bo", "in", "ro", "ngắn","li","ba", "24","ông","su","20", "10",\
                         "hong", "kho", "ma", "02", "các", "ve", "run", "hiệu", "hương", "thương", "độ", "động", "ẩn", "mềm",\
                        "gu", "hán", "kháng", "lót", "thoải", "mái","khuẩn", "phố", "phối", "ống", "đô","01","gió", "khoá", "liệu",\
                            "me", "tiết"]

# %%
infor_1w_df = infor_1w_df.drop(infor_1w_df[infor_1w_df['Word'].isin(stopwords_1w)].index)
infor_1w_df.reset_index(drop=True, inplace=True)

# %%
infor_1w_df.sort_values(by='Count',ascending=False)[:20]
# Out:
#        Word  Count  Total Sold  Approximate Revenue  Rating Average  \
# 0       nam   5936      214364         3.617371e+10        2.942180
# 1       tay   2551       51965         9.305763e+09        2.827932
# 31      thu   1842       78120         1.425578e+10        2.608748
# 2       màu   1797       52031         8.831446e+09        3.146235
# 3      thun   1422       71352         1.216736e+10        3.199549
# 4        cổ   1374       52693         6.104029e+09        3.035987
# 5       vải   1316       58831         8.971833e+09        3.586610
# 12      fit   1147        8799         2.862538e+09        3.889511
# 6      owen    970        3441         1.806392e+09        4.142010
# 7    cotton    933       45184         8.910313e+09        3.370550
# 8       mùa    869        5068         1.076681e+09        0.653294
# 9        nữ    841       16019         2.058862e+09        2.153528
# 10     xanh    834        2152         8.160944e+08        2.855940
# 11     polo    787       43794         8.367698e+09        3.317774
# 13       hè    762         482         8.647310e+07        0.586430
# 14     rộng    735        5577         9.130681e+08        1.640790
# 15   thoáng    722       29679         4.200489e+09        4.042508
# 16      mới    711        7588         1.091871e+09        1.024432
# 17     giãn    703       42800         6.280394e+09        4.003808
# 124      ấm    641       21854         3.953984e+09        3.659873
#
#      Shopee Mall  SM Rating Average  SM Approximate Revenue  SM Sold  \
# 0           2639           4.486537            3.577876e+10   212723
# 1           1291           4.418483            9.198045e+09    51572
# 31           744           4.624849            1.417670e+10    77605
# 2            976           4.249898            8.758880e+09    51677
# 3            709           4.634148            1.215302e+10    71162
# 4            687           4.584183            5.992547e+09    52178
# 5            686           4.494914            8.878598e+09    58353
# 12           995           4.287464            2.853248e+09     8766
# 6            970           4.142010            1.806392e+09     3441
# 7            598           4.618639            8.902878e+09    45139
# 8             43           4.776635            1.040144e+09     4841
# 9            329           4.274077            2.038045e+09    15877
# 10           392           4.146018            7.618923e+08     2004
# 11           498           4.584893            8.359092e+09    43769
# 13            28           4.729946            7.212400e+07      404
# 14           231           4.436247            8.993759e+08     5487
# 15           448           4.630858            4.192269e+09    29521
# 16            88           4.443512            1.081901e+09     7532
# 17           424           4.572464            6.265684e+09    42601
# 124          365           4.452748            3.860254e+09    21367
#
#      Normal Shop  NS Rating Average  NS Approximate Revenue  NS Sold
# 0           3297           1.706040             394954087.0     1641
# 1           1260           1.198249             107718529.0      393
# 31          1098           1.242647              79076934.0      515
# 2            821           1.834206              72565764.0      354
# 3            713           1.772999              14338344.0      190
# 4            687           1.487792             111481998.0      515
# 5            630           2.597568              93234760.0      478
# 12           152           1.284488               9289509.0       33
# 6              0                NaN                     0.0        0
# 7            335           1.142618               7435409.0       45
# 8            826           0.438641              36537268.0      227
# 9            512           0.790909              20816652.0      142
# 10           442           1.711799              54202100.0      148
# 11           289           1.134295               8606116.0       25
# 13           734           0.428367              14349099.0       78
# 14           504           0.359538              13692202.0       90
# 15           274           3.080533               8219421.0      158
# 16           623           0.541480               9969951.0       56
# 17           279           3.139614              14710043.0      199
# 124          276           2.611324              93730266.0      487

# %%
# infor_1w_df.to_csv('Infor_1w.csv',index=False,header=True,encoding="utf-8-sig")

# %%
# documents = list(top_50_items_SM_df['name'])
documents = list(analyzed_df['name']) 
stopwords = None
Word, Count = tokenize_k_word(documents, 2, stopwords)
infor_2w_df = pd.DataFrame({'Word': Word, 'Count': Count})
infor_best_2w_df = infor_2w_df.sort_values(by='Count',ascending=False)[:1000]
infor_best_2w_df.reset_index(drop=True, inplace=True)
infor_best_2w_df
# Out:
#             Word  Count
# 0     thời trang   2149
# 1          sơ mi   1560
# 2          áo sơ   1520
# 3        cao cấp   1427
# 4         có sẵn   1186
# ..           ...    ...
# 995  coolmate cw     18
# 996       hở vai     18
# 997       nữ đen     18
# 998       mềm co     18
# 999    kong thời     18
#
# [1000 rows x 2 columns]

# %%
top_shopee_mall_id = list(map(str, top_shopee_mall_id))
normal_shop_id = list(map(str, normal_shop_id))
list_total_sold = []
list_rating_average = []
list_arevenue = []
list_n_shop_mall = []
list_sm_ra = []
list_sm_sold = []
list_sm_arevenue = []
list_n_normal_shop = []
list_ns_ra = []
list_ns_sold = []
list_ns_arevenue = []
for keyword in infor_best_2w_df['Word']: 
    # Kiểm tra xem các giá trị trong cột 'Column' có chứa chuỗi cụ thể hay không
    contains_search_string = analyzed_df['name'].str.lower().str.contains(keyword)
    total_sold = analyzed_df[contains_search_string]['sold'].sum()
    list_total_sold.append(total_sold)
    rating_average = analyzed_df[contains_search_string]['rating_star'].mean()
    list_rating_average.append(rating_average)
    arevenue = analyzed_df[contains_search_string]['approximate_revenue'].sum()
    list_arevenue.append(arevenue)
    # SM
    n_shop_mall = analyzed_df[contains_search_string]['shopid'].isin(top_shopee_mall_id).sum()
    list_n_shop_mall.append(n_shop_mall)
    sm_ra = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(top_shopee_mall_id)]['rating_star'].mean()
    list_sm_ra.append(sm_ra)
    sm_sold = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(top_shopee_mall_id)]['sold'].sum()
    list_sm_sold.append(sm_sold)
    sm_arevenue = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(top_shopee_mall_id)]['approximate_revenue'].sum()
    list_sm_arevenue.append(sm_arevenue)
    # NS
    n_normal_shop = analyzed_df[contains_search_string]['shopid'].isin(normal_shop_id).sum()
    list_n_normal_shop.append(n_normal_shop)
    ns_ra = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(normal_shop_id)]['rating_star'].mean()
    list_ns_ra.append(ns_ra)
    ns_sold = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(normal_shop_id)]['sold'].sum()
    list_ns_sold.append(ns_sold)
    ns_arevenue = analyzed_df[contains_search_string & analyzed_df['shopid'].isin(normal_shop_id)]['approximate_revenue'].sum()
    list_ns_arevenue.append(ns_arevenue)

# %%
# infor_popular_best_2w_df = infor_best_2w_df.copy()
# infor_popular_best_2w_df['Sold'] = list_sold
# infor_popular_best_2w_df['Rating_Average'] = list_rating_average
# infor_popular_best_2w_df['Shopee_Mall'] = list_shop_mall
# infor_popular_best_2w_df['Normal_Shop'] = list_normal_shop
# infor_popular_best_2w_df.sort_values(by='Sold',ascending=False)
infor_2w_df = infor_best_2w_df.copy()
infor_2w_df['Total Sold'] = list_total_sold
infor_2w_df['Approximate Revenue'] = list_arevenue
infor_2w_df['Rating Average'] = list_rating_average
infor_2w_df['Shopee Mall'] = list_n_shop_mall
infor_2w_df['SM Rating Average'] = list_sm_ra
infor_2w_df['SM Approximate Revenue'] = list_sm_arevenue
infor_2w_df['SM Sold'] = list_sm_sold
infor_2w_df['Normal Shop'] = list_n_normal_shop
infor_2w_df['NS Rating Average'] = list_ns_ra
infor_2w_df['NS Approximate Revenue'] = list_ns_arevenue
infor_2w_df['NS Sold'] = list_ns_sold
infor_2w_df['Count'] = infor_2w_df['Shopee Mall'] + infor_2w_df['Normal Shop']

# %%
infor_2w_df = infor_2w_df[infor_2w_df['Count'] != 0]
len(infor_2w_df)
# Out:
# 963

# %%
stopwords_2w = ["áo sơ", 'hàng có', 'mi nam', 'trang mùa','ảnh 100','cấp chuẩn','owen áo','qc cao','dành cho','nam tay','mi dài','sẵn quần','nam owen',\
                'thun nam', 'polo nam', 'cách hàn','tay nam','nam cổ','thao nam','trong vòng','vòng 24','khoác nam','đùi nam','hè cho','cổ bẻ','hàng sẵn',\
                'mi ngắn','xanh mã','trang xuân','short nam','lót nam','trang hàn',"nam thể"]

# %%
infor_2w_df = infor_2w_df.drop(infor_2w_df[infor_2w_df['Word'].isin(stopwords_2w)].index)
infor_2w_df.reset_index(drop=True, inplace=True)
infor_2w_df[:20]
# Out:
#            Word  Count  Total Sold  Approximate Revenue  Rating Average  \
# 0    thời trang   2121       32098         4.290857e+09        1.511215
# 1         sơ mi   1549        6440         2.270745e+09        3.089836
# 2       cao cấp   1416       35579         6.607730e+09        2.832964
# 3        có sẵn    761          89         1.680400e+07        0.243440
# 4    phong cách   1094        9081         1.444885e+09        1.334832
# 5       áo thun   1080       55001         1.040989e+10        2.830609
# 6       cho nam   1085         492         7.699448e+07        0.569095
# 7      áo khoác    805       13071         3.569927e+09        2.311608
# 8      thể thao    781       71693         1.063720e+10        3.218890
# 9      hàn quốc    788       12067         1.590278e+09        2.463674
# 10      dài tay    724       21489         5.025779e+09        3.696865
# 11      co giãn    701       42800         6.280394e+09        4.008098
# 12       mùa hè    681         473         8.484040e+07        0.606010
# 13    chất liệu    659        8755         1.866805e+09        3.640634
# 14     ngắn tay    653        6773         1.134032e+09        3.212853
# 15   quần short    642       11843         2.040216e+09        2.174443
# 16      áo polo    548       31715         6.513495e+09        3.904995
# 17     họa tiết    540        4140         6.002152e+08        1.529679
# 18     tay ngắn    541        3536         5.935357e+08        2.084639
# 19  thương hiệu    540       47412         9.494860e+09        4.117166
#
#     Shopee Mall  SM Rating Average  SM Approximate Revenue  SM Sold  \
# 0           523           4.599648            4.230485e+09    31823
# 1           768           4.369255            2.199263e+09     6211
# 2           500           4.518186            6.410606e+09    34815
# 3             0                NaN            0.000000e+00        0
# 4           252           4.394619            1.423875e+09     8980
# 5           588           4.609981            1.040126e+10    54970
# 6            10           4.889855            3.455563e+07      244
# 7           268           4.191883            3.438588e+09    12589
# 8           427           4.730099            1.060909e+10    71566
# 9           317           4.547781            1.563235e+09    11961
# 10          537           4.381065            5.004420e+09    21408
# 11          423           4.583273            6.265684e+09    42601
# 12           28           4.729946            7.212400e+07      404
# 13          530           4.100457            1.853584e+09     8722
# 14          424           4.363979            1.119626e+09     6723
# 15          241           4.458084            2.031574e+09    11803
# 16          442           4.557154            6.512171e+09    31709
# 17          122           4.440692            5.796382e+08     4096
# 18          139           4.617182            5.682800e+08     3477
# 19          380           4.683213            9.490071e+09    47328
#
#     Normal Shop  NS Rating Average  NS Approximate Revenue  NS Sold
# 0          1598           0.500420              60371632.0      275
# 1           781           1.831713              71482194.0      229
# 2           916           1.913083             197124724.0      764
# 3           761           0.243440              16803995.0       89
# 4           842           0.419077              21010391.0      101
# 5           492           0.704042               8624463.0       31
# 6          1075           0.528902              42438853.0      248
# 7           537           1.373221             131338160.0      482
# 8           354           1.396048              28111396.0      127
# 9           471           1.060995              27043097.0      106
# 10          187           1.732076              21358529.0       81
# 11          278           3.132922              14710043.0      199
# 12          653           0.429180              12716400.0       69
# 13          129           1.751436              13221000.0       33
# 14          229           1.081510              14405542.0       50
# 15          401           0.801981               8642132.0       40
# 16          106           1.185613               1324616.0        6
# 17          418           0.680054              20577042.0       44
# 18          402           1.208959              25255722.0       59
# 19          160           2.772804               4788400.0       84

# %%
infor_2w_df.sort_values(by='Total Sold',ascending=False)[:20]
# Out:
#               Word  Count  Total Sold  Approximate Revenue  Rating Average  \
# 8         thể thao    781       71693         1.063720e+10        3.218890
# 5          áo thun   1080       55001         1.040989e+10        2.830609
# 19     thương hiệu    540       47412         9.494860e+09        4.117166
# 33   hiệu coolmate    322       43113         9.031805e+09        4.655202
# 11         co giãn    701       42800         6.280394e+09        4.008098
# 2          cao cấp   1416       35579         6.607730e+09        2.832964
# 38       thoải mái    281       33451         5.007692e+09        4.309984
# 0       thời trang   2121       32098         4.290857e+09        1.511215
# 16         áo polo    548       31715         6.513495e+09        3.904995
# 24       trẻ trung    450       29774         5.744629e+09        3.522422
# 124    kháng khuẩn    113       28601         2.702846e+09        4.531792
# 39        quần lót    272       28103         5.022340e+09        4.439552
# 42        chất vải    278       24378         2.518770e+09        4.329045
# 90          cá sấu    135       23905         3.584032e+09        4.180075
# 36      thoáng khí    317       22855         3.262564e+09        3.486427
# 146     nam guzado     99       22092         2.175823e+09        4.652687
# 10         dài tay    724       21489         5.025779e+09        3.696865
# 92        vận động    131       21146         2.572029e+09        4.599930
# 356        chất nỉ     45       18001         3.651606e+09        4.622446
# 51         mềm mại    244       16644         2.244858e+09        4.182592
#
#      Shopee Mall  SM Rating Average  SM Approximate Revenue  SM Sold  \
# 8            427           4.730099            1.060909e+10    71566
# 5            588           4.609981            1.040126e+10    54970
# 19           380           4.683213            9.490071e+09    47328
# 33           322           4.655202            9.031805e+09    43113
# 11           423           4.583273            6.265684e+09    42601
# 2            500           4.518186            6.410606e+09    34815
# 38           230           4.580698            5.005186e+09    33423
# 0            523           4.599648            4.230485e+09    31823
# 16           442           4.557154            6.512171e+09    31709
# 24           315           4.453061            5.737637e+09    29755
# 124          107           4.619244            2.702764e+09    28600
# 39           138           4.777804            5.017551e+09    27993
# 42            77           4.656172            2.491574e+09    24192
# 90           115           4.778240            3.584032e+09    23905
# 36           194           4.712332            3.257747e+09    22757
# 146           99           4.652687            2.175823e+09    22092
# 10           537           4.381065            5.004420e+09    21408
# 92            89           4.618579            2.570193e+09    21091
# 356           43           4.622973            3.651606e+09    18001
# 51           222           4.427353            2.244200e+09    16640
#
#      Normal Shop  NS Rating Average  NS Approximate Revenue  NS Sold
# 8            354           1.396048              28111396.0      127
# 5            492           0.704042               8624463.0       31
# 19           160           2.772804               4788400.0       84
# 33             0                NaN                     0.0        0
# 11           278           3.132922              14710043.0      199
# 2            916           1.913083             197124724.0      764
# 38            51           3.089119               2505894.0       28
# 0           1598           0.500420              60371632.0      275
# 16           106           1.185613               1324616.0        6
# 24           135           1.350931               6991571.0       19
# 124            6           2.972222                 82080.0        1
# 39           134           4.091203               4788382.0      110
# 42           201           4.203728              27196042.0      186
# 90            20           0.740625                     0.0        0
# 36           123           1.552884               4816604.0       98
# 146            0                NaN                     0.0        0
# 10           187           1.732076              21358529.0       81
# 92            42           4.560412               1836313.0       55
# 356            2           4.611111                     0.0        0
# 51            22           1.712727                658063.0        4

# %%
infor_2w_df.sort_values(by='Count',ascending=False)[:20]
# Out:
#            Word  Count  Total Sold  Approximate Revenue  Rating Average  \
# 0    thời trang   2121       32098         4.290857e+09        1.511215
# 1         sơ mi   1549        6440         2.270745e+09        3.089836
# 2       cao cấp   1416       35579         6.607730e+09        2.832964
# 4    phong cách   1094        9081         1.444885e+09        1.334832
# 6       cho nam   1085         492         7.699448e+07        0.569095
# 5       áo thun   1080       55001         1.040989e+10        2.830609
# 7      áo khoác    805       13071         3.569927e+09        2.311608
# 9      hàn quốc    788       12067         1.590278e+09        2.463674
# 8      thể thao    781       71693         1.063720e+10        3.218890
# 3        có sẵn    761          89         1.680400e+07        0.243440
# 10      dài tay    724       21489         5.025779e+09        3.696865
# 11      co giãn    701       42800         6.280394e+09        4.008098
# 12       mùa hè    681         473         8.484040e+07        0.606010
# 13    chất liệu    659        8755         1.866805e+09        3.640634
# 14     ngắn tay    653        6773         1.134032e+09        3.212853
# 15   quần short    642       11843         2.040216e+09        2.174443
# 16      áo polo    548       31715         6.513495e+09        3.904995
# 18     tay ngắn    541        3536         5.935357e+08        2.084639
# 17     họa tiết    540        4140         6.002152e+08        1.529679
# 19  thương hiệu    540       47412         9.494860e+09        4.117166
#
#     Shopee Mall  SM Rating Average  SM Approximate Revenue  SM Sold  \
# 0           523           4.599648            4.230485e+09    31823
# 1           768           4.369255            2.199263e+09     6211
# 2           500           4.518186            6.410606e+09    34815
# 4           252           4.394619            1.423875e+09     8980
# 6            10           4.889855            3.455563e+07      244
# 5           588           4.609981            1.040126e+10    54970
# 7           268           4.191883            3.438588e+09    12589
# 9           317           4.547781            1.563235e+09    11961
# 8           427           4.730099            1.060909e+10    71566
# 3             0                NaN            0.000000e+00        0
# 10          537           4.381065            5.004420e+09    21408
# 11          423           4.583273            6.265684e+09    42601
# 12           28           4.729946            7.212400e+07      404
# 13          530           4.100457            1.853584e+09     8722
# 14          424           4.363979            1.119626e+09     6723
# 15          241           4.458084            2.031574e+09    11803
# 16          442           4.557154            6.512171e+09    31709
# 18          139           4.617182            5.682800e+08     3477
# 17          122           4.440692            5.796382e+08     4096
# 19          380           4.683213            9.490071e+09    47328
#
#     Normal Shop  NS Rating Average  NS Approximate Revenue  NS Sold
# 0          1598           0.500420              60371632.0      275
# 1           781           1.831713              71482194.0      229
# 2           916           1.913083             197124724.0      764
# 4           842           0.419077              21010391.0      101
# 6          1075           0.528902              42438853.0      248
# 5           492           0.704042               8624463.0       31
# 7           537           1.373221             131338160.0      482
# 9           471           1.060995              27043097.0      106
# 8           354           1.396048              28111396.0      127
# 3           761           0.243440              16803995.0       89
# 10          187           1.732076              21358529.0       81
# 11          278           3.132922              14710043.0      199
# 12          653           0.429180              12716400.0       69
# 13          129           1.751436              13221000.0       33
# 14          229           1.081510              14405542.0       50
# 15          401           0.801981               8642132.0       40
# 16          106           1.185613               1324616.0        6
# 18          402           1.208959              25255722.0       59
# 17          418           0.680054              20577042.0       44
# 19          160           2.772804               4788400.0       84

# %%
infor_2w_df.to_csv('Infor_2w.csv',index=False,header=True,encoding="utf-8-sig")

# %%
infor_2w_df[:20]
# Out:
#            Word  Count  Total Sold  Approximate Revenue  Rating Average  \
# 0    thời trang   2121       32098         4.290857e+09        1.511215
# 1         sơ mi   1549        6440         2.270745e+09        3.089836
# 2       cao cấp   1416       35579         6.607730e+09        2.832964
# 3        có sẵn    761          89         1.680400e+07        0.243440
# 4    phong cách   1094        9081         1.444885e+09        1.334832
# 5       áo thun   1080       55001         1.040989e+10        2.830609
# 6       cho nam   1085         492         7.699448e+07        0.569095
# 7      áo khoác    805       13071         3.569927e+09        2.311608
# 8      thể thao    781       71693         1.063720e+10        3.218890
# 9      hàn quốc    788       12067         1.590278e+09        2.463674
# 10      dài tay    724       21489         5.025779e+09        3.696865
# 11      co giãn    701       42800         6.280394e+09        4.008098
# 12       mùa hè    681         473         8.484040e+07        0.606010
# 13    chất liệu    659        8755         1.866805e+09        3.640634
# 14     ngắn tay    653        6773         1.134032e+09        3.212853
# 15   quần short    642       11843         2.040216e+09        2.174443
# 16      áo polo    548       31715         6.513495e+09        3.904995
# 17     họa tiết    540        4140         6.002152e+08        1.529679
# 18     tay ngắn    541        3536         5.935357e+08        2.084639
# 19  thương hiệu    540       47412         9.494860e+09        4.117166
#
#     Shopee Mall  SM Rating Average  SM Approximate Revenue  SM Sold  \
# 0           523           4.599648            4.230485e+09    31823
# 1           768           4.369255            2.199263e+09     6211
# 2           500           4.518186            6.410606e+09    34815
# 3             0                NaN            0.000000e+00        0
# 4           252           4.394619            1.423875e+09     8980
# 5           588           4.609981            1.040126e+10    54970
# 6            10           4.889855            3.455563e+07      244
# 7           268           4.191883            3.438588e+09    12589
# 8           427           4.730099            1.060909e+10    71566
# 9           317           4.547781            1.563235e+09    11961
# 10          537           4.381065            5.004420e+09    21408
# 11          423           4.583273            6.265684e+09    42601
# 12           28           4.729946            7.212400e+07      404
# 13          530           4.100457            1.853584e+09     8722
# 14          424           4.363979            1.119626e+09     6723
# 15          241           4.458084            2.031574e+09    11803
# 16          442           4.557154            6.512171e+09    31709
# 17          122           4.440692            5.796382e+08     4096
# 18          139           4.617182            5.682800e+08     3477
# 19          380           4.683213            9.490071e+09    47328
#
#     Normal Shop  NS Rating Average  NS Approximate Revenue  NS Sold
# 0          1598           0.500420              60371632.0      275
# 1           781           1.831713              71482194.0      229
# 2           916           1.913083             197124724.0      764
# 3           761           0.243440              16803995.0       89
# 4           842           0.419077              21010391.0      101
# 5           492           0.704042               8624463.0       31
# 6          1075           0.528902              42438853.0      248
# 7           537           1.373221             131338160.0      482
# 8           354           1.396048              28111396.0      127
# 9           471           1.060995              27043097.0      106
# 10          187           1.732076              21358529.0       81
# 11          278           3.132922              14710043.0      199
# 12          653           0.429180              12716400.0       69
# 13          129           1.751436              13221000.0       33
# 14          229           1.081510              14405542.0       50
# 15          401           0.801981               8642132.0       40
# 16          106           1.185613               1324616.0        6
# 17          418           0.680054              20577042.0       44
# 18          402           1.208959              25255722.0       59
# 19          160           2.772804               4788400.0       84

# %%
# infor_2w_df.to_csv('Infor_2w.csv',index=False,header=True,encoding="utf-8-sig")

# %%
infor_2w_df.sort_values(by='Total Sold',ascending=False)[:50]
# Out:
#               Word  Count  Total Sold  Approximate Revenue  Rating Average  \
# 8         thể thao    781       71693         1.063720e+10        3.218890
# 5          áo thun   1080       55001         1.040989e+10        2.830609
# 19     thương hiệu    540       47412         9.494860e+09        4.117166
# 33   hiệu coolmate    322       43113         9.031805e+09        4.655202
# 11         co giãn    701       42800         6.280394e+09        4.008098
# 2          cao cấp   1416       35579         6.607730e+09        2.832964
# 38       thoải mái    281       33451         5.007692e+09        4.309984
# 0       thời trang   2121       32098         4.290857e+09        1.511215
# 16         áo polo    548       31715         6.513495e+09        3.904995
# 24       trẻ trung    450       29774         5.744629e+09        3.522422
# 124    kháng khuẩn    113       28601         2.702846e+09        4.531792
# 39        quần lót    272       28103         5.022340e+09        4.439552
# 42        chất vải    278       24378         2.518770e+09        4.329045
# 90          cá sấu    135       23905         3.584032e+09        4.180075
# 36      thoáng khí    317       22855         3.262564e+09        3.486427
# 146     nam guzado     99       22092         2.175823e+09        4.652687
# 10         dài tay    724       21489         5.025779e+09        3.696865
# 92        vận động    131       21146         2.572029e+09        4.599930
# 356        chất nỉ     45       18001         3.651606e+09        4.622446
# 51         mềm mại    244       16644         2.244858e+09        4.182592
# 345     động thoải     47       16459         1.914888e+09        4.884485
# 60       năng động    201       16330         2.934472e+09        2.556074
# 205         bộ thể     73       15616         3.381377e+09        4.094053
# 362       cạp chun     45       15439         2.033044e+09        4.879534
# 121   thun levents    114       14947         5.046151e+09        4.802377
# 41        thấm hút    279       14701         2.067993e+09        4.619173
# 186       nam chất     62       14663         2.989216e+09        4.246235
# 809        tất nam     21       14411         3.218460e+08        4.378788
# 54         mềm mịn    225       14377         1.868181e+09        4.239622
# 139       quần đùi    102       14098         1.416532e+09        4.658643
# 372        đôi tất     43       14087         5.402882e+08        3.953113
# 225        vải gió     70       13764         1.656148e+09        4.181134
# 112     5s fashion    117       13099         2.583420e+09        4.680647
# 7         áo khoác    805       13071         3.569927e+09        2.311608
# 34         dày dặn    322       13048         2.706289e+09        2.990055
# 30        thiết kế    337       13017         2.807021e+09        3.847642
# 46      sang trọng    269       12226         3.388885e+09        3.442073
# 37          nam nữ    309       12100         1.610036e+09        3.369166
# 9         hàn quốc    788       12067         1.590278e+09        2.463674
# 15      quần short    642       11843         2.040216e+09        2.174443
# 801       viền tay     21       11689         9.406160e+08        3.241890
# 66      thanh lịch    169       11669         3.300026e+09        4.206649
# 185       nam tính     79       11063         3.071066e+09        4.476194
# 226      giữ nhiệt     66       10907         1.921343e+09        4.189967
# 61        vải thun    199       10781         7.860811e+08        4.699990
# 26         cổ tròn    430       10698         1.878750e+09        2.900301
# 217         vải cá     70       10651         2.668991e+09        4.492616
# 216  trang everest     71       10506         6.436333e+08        4.823904
# 191        cổ ngắn     79       10459         4.135875e+08        3.792631
# 199      nhiều màu     75       10398         8.088230e+08        4.059903
#
#      Shopee Mall  SM Rating Average  SM Approximate Revenue  SM Sold  \
# 8            427           4.730099            1.060909e+10    71566
# 5            588           4.609981            1.040126e+10    54970
# 19           380           4.683213            9.490071e+09    47328
# 33           322           4.655202            9.031805e+09    43113
# 11           423           4.583273            6.265684e+09    42601
# 2            500           4.518186            6.410606e+09    34815
# 38           230           4.580698            5.005186e+09    33423
# 0            523           4.599648            4.230485e+09    31823
# 16           442           4.557154            6.512171e+09    31709
# 24           315           4.453061            5.737637e+09    29755
# 124          107           4.619244            2.702764e+09    28600
# 39           138           4.777804            5.017551e+09    27993
# 42            77           4.656172            2.491574e+09    24192
# 90           115           4.778240            3.584032e+09    23905
# 36           194           4.712332            3.257747e+09    22757
# 146           99           4.652687            2.175823e+09    22092
# 10           537           4.381065            5.004420e+09    21408
# 92            89           4.618579            2.570193e+09    21091
# 356           43           4.622973            3.651606e+09    18001
# 51           222           4.427353            2.244200e+09    16640
# 345           47           4.884485            1.914888e+09    16459
# 60           102           4.636479            2.933007e+09    16324
# 205           49           4.805371            3.380343e+09    15613
# 362           42           4.887596            2.032288e+09    15435
# 121          114           4.802377            5.046151e+09    14947
# 41           172           4.716010            2.064335e+09    14635
# 186           34           4.688203            2.972324e+09    14624
# 809           17           4.320071            3.214410e+08    14408
# 54           195           4.389853            1.844489e+09    14244
# 139           93           4.789853            1.415666e+09    14088
# 372           31           4.410769            5.400410e+08    14082
# 225           55           4.603972            1.648657e+09    13724
# 112          117           4.680647            2.583420e+09    13099
# 7            268           4.191883            3.438588e+09    12589
# 34           181           4.408920            2.694983e+09    13014
# 30           266           4.663881            2.806500e+09    13015
# 46           182           4.396589            3.372687e+09    12177
# 37           206           4.235247            1.605829e+09    12062
# 9            317           4.547781            1.563235e+09    11961
# 15           241           4.458084            2.031574e+09    11803
# 801           14           4.862835            9.406160e+08    11689
# 66           156           4.285836            3.295488e+09    11666
# 185           71           4.854142            3.070822e+09    11062
# 226           48           4.498216            1.909002e+09    10825
# 61            34           4.919099            7.819876e+08    10637
# 26           215           4.637561            1.856188e+09    10618
# 217           63           4.896557            2.668991e+09    10651
# 216           71           4.823904            6.436333e+08    10506
# 191           38           4.646765            4.121160e+08    10427
# 199           57           4.860573            8.085298e+08    10395
#
#      Normal Shop  NS Rating Average  NS Approximate Revenue  NS Sold
# 8            354           1.396048              28111396.0      127
# 5            492           0.704042               8624463.0       31
# 19           160           2.772804               4788400.0       84
# 33             0                NaN                     0.0        0
# 11           278           3.132922              14710043.0      199
# 2            916           1.913083             197124724.0      764
# 38            51           3.089119               2505894.0       28
# 0           1598           0.500420              60371632.0      275
# 16           106           1.185613               1324616.0        6
# 24           135           1.350931               6991571.0       19
# 124            6           2.972222                 82080.0        1
# 39           134           4.091203               4788382.0      110
# 42           201           4.203728              27196042.0      186
# 90            20           0.740625                     0.0        0
# 36           123           1.552884               4816604.0       98
# 146            0                NaN                     0.0        0
# 10           187           1.732076              21358529.0       81
# 92            42           4.560412               1836313.0       55
# 356            2           4.611111                     0.0        0
# 51            22           1.712727                658063.0        4
# 345            0                NaN                     0.0        0
# 60            99           0.412626               1465598.0        6
# 205           24           2.641778               1034000.0        3
# 362            3           4.766667                756000.0        4
# 121            0                NaN                     0.0        0
# 41           107           4.463510               3658199.0       66
# 186           28           3.709560              16891000.0       39
# 809            4           4.628333                405000.0        3
# 54            30           3.263119              23691300.0      133
# 139            9           3.302802                865989.0       10
# 372           12           2.770833                247200.0        5
# 225           15           2.630727               7491000.0       40
# 112            0                NaN                     0.0        0
# 7            537           1.373221             131338160.0      482
# 34           141           1.168676              11306253.0       34
# 30            71           0.789622                521064.0        2
# 46            87           1.445268              16197598.0       49
# 37           103           1.637004               4206578.0       38
# 9            471           1.060995              27043097.0      106
# 15           401           0.801981               8642132.0       40
# 801            7           0.000000                     0.0        0
# 66            13           3.256410               4538000.0        3
# 185            8           1.121904                244500.0        1
# 226           18           3.367969              12341040.0       82
# 61           165           4.654840               4093532.0      144
# 26           215           1.163041              22562446.0       80
# 217            7           0.857143                     0.0        0
# 216            0                NaN                     0.0        0
# 191           41           3.000995               1471500.0       32
# 199           18           1.524446                293200.0        3

# %%
shop_infor_df = pd.read_csv("Malls_Information.csv",encoding="utf-8-sig")
shop_infor_df = shop_infor_df[['shopid','name']]
shop_infor_df
# Out:
#        shopid                            name
# 0    40342563                 Aviano Menswear
# 1   225909574                       POLOMANOR
# 2    68613764  TSLA Store Quần áo legging nam
# 3    24710134       Coolmate - Official Store
# 4   127217331             5S FASHION OFFICIAL
# 5    60297616                           ROUGH
# 6   111639450                         Pattern
# 7   317477677                     Levents .vn
# 8   201774917                 Guzado Official
# 9    59596762                Thời Trang MANDO
# 10  168678363                TSIMPLE_OFFICIAL
# 11   92937520             Thời trang nam Owen
# 12   68988783               Biluxury Official
# 13  263713672             FEAER STORE PREMIUM
# 14   38038824           SUKIYA OFFICIAL STORE
# 15  277366270                   4MEN OFFICIAL
# 16   70677296                BAO DANG fashion
# 17    1620236                         4U SHOP
# 18   17893078             THỜI TRANG EVEREST
# 19   31522834                 Kojiba Việt Nam
# 20   16649961  HARAS VietNam - Official Store
# 21  296132807              SAIGONESE.Clothing
# 22  257412160                           AREMI

# %%
len(shop_infor_df)
# Out:
# 23

# %%
# infor_2w_df.sort_values(by='Total Sold',ascending=False)[:50]
# # Nhớ remove 1 vài dòng bị trùng ý nghĩa hoặc không cần thiết trong top 50:
# # Thương hiệu
top_20_infor_1w_df = infor_1w_df.sort_values(by='Count',ascending=False)[:20]

# %%
top_1word = list(top_20_infor_1w_df['Word'])

# %%
list_shop_name = []
list_item_name = []
list_keyword = []
list_sold = []
list_rating = []
list_arevenue = []

# %%
for keyword in top_1word:
    for i in range(0,len(shop_infor_df)):
        temp_df = analyzed_df[analyzed_df['shopid'] == str(shop_infor_df['shopid'][i])]
        contains_search_string = temp_df['name'].str.lower().str.contains(keyword)
        
        for item_name in temp_df[contains_search_string]['name']:
            list_shop_name.append(shop_infor_df['name'][i])
            list_item_name.append(item_name)
            list_keyword.append(keyword)
            list_sold.append(temp_df[contains_search_string & (temp_df['name'] == item_name)]['sold'].values[0])
            list_rating.append(temp_df[contains_search_string & (temp_df['name'] == item_name)]['rating_star'].values[0])
            arevenue = temp_df[contains_search_string & (temp_df['name'] == item_name)]['sold'].values[0] * \
            temp_df[contains_search_string & (temp_df['name'] == item_name)]['price'].values[0]
            list_arevenue.append(arevenue)

# %%
SM_1w_df = pd.DataFrame({'shop_name': list_shop_name, 'item_name':list_item_name, 'keyword': list_keyword,\
                               'sold': list_sold, 'rating': list_rating, 'approximate revenue': list_arevenue})

# %%
SM_1w_df
# Out:
#                             shop_name  \
# 0                     Aviano Menswear
# 1                     Aviano Menswear
# 2                     Aviano Menswear
# 3                     Aviano Menswear
# 4                     Aviano Menswear
# ...                               ...
# 13136  HARAS VietNam - Official Store
# 13137                           AREMI
# 13138                           AREMI
# 13139                           AREMI
# 13140                           AREMI
#
#                                                item_name keyword  sold  \
# 0       Bộ Thể Thao Nam 4 Màu Trẻ Trung Nặng Động VICERO     nam    62
# 1      Áo Khoác Nam Chất Liệu Cao Cấp Kiểu Dáng Trẻ T...     nam     5
# 2      Áo Khoác Thể Thao Nam 3 Màu Trẻ Trung Cao Cấp ...     nam    84
# 3      Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...     nam  3912
# 4      Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Đ...     nam  6595
# ...                                                  ...     ...   ...
# 13136  Balo nam nữ thời trang Hàn quốc chống thấm nướ...      ấm     0
# 13137  Áo thun polo có cổ tay dài nam AREMI chất liệu...      ấm     0
# 13138  Áo thun nam tay raglan AREMI t-shirt trơn cổ t...      ấm     9
# 13139  Áo thun nam cổ tròn tay ngắn AREMI vải cotton ...      ấm    27
# 13140  Áo thun polo nam có cổ tay dài nam AREMI chất ...      ấm     3
#
#          rating  approximate revenue
# 0      4.906764         1.047800e+07
# 1      4.848684         6.450000e+05
# 2      4.839286         1.083600e+07
# 3      4.847720         7.628400e+08
# 4      4.846812         1.220075e+09
# ...         ...                  ...
# 13136  0.000000         0.000000e+00
# 13137  0.000000         0.000000e+00
# 13138  5.000000         1.341000e+06
# 13139  4.910979         4.833000e+06
# 13140  5.000000         5.970000e+05
#
# [13141 rows x 6 columns]

# %%
# SM_1w_df.to_csv('SM_1w.csv',index=False,header=True,encoding="utf-8-sig")

# %%
# infor_2w_df.sort_values(by='Total Sold',ascending=False)[:50]
# # Nhớ remove 1 vài dòng bị trùng ý nghĩa hoặc không cần thiết trong top 50:
# # Thương hiệu
top_20_infor_2w_df = infor_2w_df.sort_values(by='Count',ascending=False)[:20]

# %%
top_2word = list(top_20_infor_2w_df['Word'])

# %%
list_shop_name = []
list_item_name = []
list_keyword = []
list_sold = []
list_rating = []
list_arevenue = []

# %%
for keyword in top_2word:
    for i in range(0,len(shop_infor_df)):
        temp_df = analyzed_df[analyzed_df['shopid'] == str(shop_infor_df['shopid'][i])]
        contains_search_string = temp_df['name'].str.lower().str.contains(keyword)
        
        for item_name in temp_df[contains_search_string]['name']:
            list_shop_name.append(shop_infor_df['name'][i])
            list_item_name.append(item_name)
            list_keyword.append(keyword)
            list_sold.append(temp_df[contains_search_string & (temp_df['name'] == item_name)]['sold'].values[0])
            list_rating.append(temp_df[contains_search_string & (temp_df['name'] == item_name)]['rating_star'].values[0])
            arevenue = temp_df[contains_search_string & (temp_df['name'] == item_name)]['sold'].values[0] * \
            temp_df[contains_search_string & (temp_df['name'] == item_name)]['price'].values[0]
            list_arevenue.append(arevenue)

# %%
SM_2w_df = pd.DataFrame({'shop_name': list_shop_name, 'item_name':list_item_name, 'keyword': list_keyword,\
                               'sold': list_sold, 'rating': list_rating, 'approximate revenue': list_arevenue})

# %%
SM_2w_df = SM_2w_df.drop(SM_2w_df[SM_2w_df['shop_name'] == 'HARAS VietNam - Official Store'].index)
SM_2w_df.reset_index(drop=True, inplace=True)

# %%
# SM_2w_df.to_csv('SM_2w.csv',index=False,header=True,encoding="utf-8-sig")

# %%
list_sm_name = []
list_sm_total_sold = []
list_sm_rating = []
list_sm_arevenue = []
for i in range(0,len(shop_infor_df)):
    temp_df = analyzed_df[analyzed_df['shopid'] == str(shop_infor_df['shopid'][i])]
    sm_name = shop_infor_df['name'][i]
    list_sm_name.append(sm_name)
    total_sold = temp_df.groupby(by=['shopid'])['sold'].sum().values[0]
    list_sm_total_sold.append(total_sold)
    rating_average = temp_df.groupby(by = ['shopid'])['rating_star'].mean().values[0]
    list_sm_rating.append(rating_average)
    arevenue = temp_df.groupby(by = ['shopid'])['approximate_revenue'].sum().values[0]
    list_sm_arevenue.append(arevenue)

# %%
SM_Infor_df = pd.DataFrame({'SM_Name': list_sm_name, 'SM_Total_Sold': list_sm_total_sold, \
                            'SM_Rating_Average': list_sm_rating, 'SM_Approximate_Revenue': list_sm_arevenue})
SM_Infor_df
# Out:
#                            SM_Name  SM_Total_Sold  SM_Rating_Average  \
# 0                  Aviano Menswear          32564           4.868854
# 1                        POLOMANOR          15959           4.843272
# 2   TSLA Store Quần áo legging nam           2361           4.670614
# 3        Coolmate - Official Store          72927           4.707948
# 4              5S FASHION OFFICIAL          14083           4.789382
# 5                            ROUGH           9333           4.558269
# 6                          Pattern           5745           4.780964
# 7                      Levents .vn          22354           4.607361
# 8                  Guzado Official          36727           4.770072
# 9                 Thời Trang MANDO           1564           4.761730
# 10                TSIMPLE_OFFICIAL           3811           4.591569
# 11             Thời trang nam Owen           3441           4.143723
# 12               Biluxury Official           4146           4.157910
# 13             FEAER STORE PREMIUM           4171           4.648271
# 14           SUKIYA OFFICIAL STORE          11240           4.462829
# 15                   4MEN OFFICIAL           1833           3.918238
# 16                BAO DANG fashion           4014           3.801418
# 17                         4U SHOP           1367           4.370863
# 18             THỜI TRANG EVEREST          21764           4.831119
# 19                 Kojiba Việt Nam            550           4.671059
# 20  HARAS VietNam - Official Store           5628           4.370803
# 21              SAIGONESE.Clothing          10261           4.509603
# 22                           AREMI           2453           4.377508
#
#     SM_Approximate_Revenue
# 0             5.567569e+09
# 1             4.110210e+09
# 2             3.679548e+08
# 3             1.356044e+10
# 4             2.848612e+09
# 5             1.196077e+09
# 6             1.010936e+09
# 7             8.519942e+09
# 8             3.922139e+09
# 9             3.019890e+08
# 10            4.369460e+08
# 11            1.806392e+09
# 12            1.311942e+09
# 13            1.072975e+09
# 14            1.847134e+09
# 15            3.655540e+08
# 16            4.108930e+08
# 17            2.201030e+08
# 18            1.287075e+09
# 19            6.712200e+07
# 20            5.719080e+08
# 21            1.655130e+09
# 22            4.024540e+08

# %%
# SM_Infor_df.to_csv('SM_Infor.csv',index=False,header=True,encoding="utf-8-sig")

# %%
def tokenize_range_word(documents, i, j, stopwords):
    preprocessed_documents = [doc.lower() for doc in documents]
    vectorizer = CountVectorizer(ngram_range= (i,j), stop_words= stopwords)
    word_counts = vectorizer.fit_transform(preprocessed_documents)
    words = vectorizer.get_feature_names_out()
    word_occurrences = word_counts.toarray().sum(axis=0)
    word_count_dict = dict(zip(words, word_occurrences))
    Word = []
    Count = []
    for word, count in word_count_dict.items():
        Word.append(word)
        Count.append(count)
    return Word, Count

# %%
SM_Unique_Word_df = pd.DataFrame({"Shop_Name": [],'Word': [],'Count': []})
SM_Unique_Word_df
# Out:
# Empty DataFrame
# Columns: [Shop_Name, Word, Count]
# Index: []

# %%
for i in range(0,len(shop_infor_df)):
        temp_df = analyzed_df[analyzed_df['shopid'] == str(shop_infor_df['shopid'][i])]
        documents = list(temp_df['name']) 
        stopwords = None
        Word, Count = tokenize_range_word(documents, 1,2, stopwords)
        Shop_Name = len(Word)* [shop_infor_df['name'][i]]
        infor_1_2w_df = pd.DataFrame({'Shop_Name': Shop_Name ,'Word': Word, 'Count': Count})
        infor_best_1_2w_df = infor_1_2w_df.sort_values(by='Count',ascending=False)[:50]
        infor_best_1_2w_df.reset_index(drop=True, inplace=True)
        SM_Unique_Word_df = pd.concat([SM_Unique_Word_df, infor_best_1_2w_df])

# %%
stopwords_unique = ['trang','thời','chất','thao','thể','nam aviano','cấp','cao','thiết','đồ','thao nam','có','bộ quần','hôi',\
                    'cá', 'sấu cotton','tính thanh', 'cmc nam','nam cổ', 'interlock xuất','xịn nam', 'nam cổ','nam phối',\
                   'phối','bẻ','bóng', 'chạy', 'giữ', 'rổ','lót', 'nhiệt','lông', 'lót lông','khuẩn','đá','nam tsla','khí',\
                    'co','giãn','nước','mái','chống','lót nam','chất','liệu','lịch','thanh','dễ','kế basic','short',\
                    'sơ', 'áo sơ', 'tăm', 'màu pattern', 'pattern the', 'khoác','da lộn','levents basic', 'polo levents', 'vớ levents',\
                    'levents my','động', 'cực', 'vận', 'kháng','mi', 'mando chất', 'unisex thời', 'mi nam','gym vải',\
                    'chuẩn', 'lạnh thoáng','tròn', 'giãn chuẩn','sấu','đùi','mi', 'mi ngắn', 'ghi','tay body','owen dáng',\
                        'tay body', 'owen dáng', 'tay regular','tây', 'polo ngắn','mịn', 'trung','sợi', 'đãi', 'trung feaer',\
                            'sản', 'nam có','ưu','đãi áo', 'mại', 'hàng','dặn','thỏ','cách','đứng', 'khoác nam','liểu', 'nắng',\
                                'siêu','sinh','lớp phối','đeo','chéo', 'trọng', 'sở','kim', 'đựng','bò dáng','cấp thời', 'hình thời',\
                                    'nam thời', 'everest nhiều','nộ', 'giản', 'nằm','chống nhãn','quốc', 'công', 'xù không', 'loại',\
                            'trang haras', 'và túi', 'du', 'trang hàn', 'xách', 'lịch thời', 'cấp haras', 'ba', 'lô','nữ màu', 'nữ đen',\
                                'tay lỡ', 'saigonese quần','saigonese cotton', 'đùi nam','nam tay','chiều', 'trụ', 'cotton co', 'liệu cá']

# %%
SM_Unique_Word_df.reset_index(drop=True, inplace=True)
SM_Unique_Word_df = SM_Unique_Word_df.drop(SM_Unique_Word_df[SM_Unique_Word_df['Word'].isin(stopwords_unique)].index)
SM_Unique_Word_df.reset_index(drop=True, inplace=True)
SM_Unique_Word_df
# Out:
#            Shop_Name        Word  Count
# 0    Aviano Menswear         nam  225.0
# 1    Aviano Menswear          áo  141.0
# 2    Aviano Menswear      aviano  118.0
# 3    Aviano Menswear        quần   95.0
# 4    Aviano Menswear  thời trang   90.0
# ..               ...         ...    ...
# 813            AREMI     ngắn cổ   20.0
# 814            AREMI         trẻ   19.0
# 815            AREMI   trẻ trung   19.0
# 816            AREMI       có cổ   18.0
# 817            AREMI    thun nam   17.0
#
# [818 rows x 3 columns]

# %%
list_shop_name = []
list_item_name = []
list_keyword = []
list_sold = []
list_rating = []
list_arevenue = []

# %%
for i in range(0,len(shop_infor_df)):
    temp_df = analyzed_df[analyzed_df['shopid'] == str(shop_infor_df['shopid'][i])]
    for keyword in SM_Unique_Word_df[SM_Unique_Word_df['Shop_Name'] == shop_infor_df['name'][i]]['Word']:
        contains_search_string = temp_df['name'].str.lower().str.contains(keyword)
        
        for item_name in temp_df[contains_search_string]['name']:
            list_shop_name.append(shop_infor_df['name'][i])
            list_item_name.append(item_name)
            list_keyword.append(keyword)
            list_sold.append(temp_df[contains_search_string & (temp_df['name'] == item_name)]['sold'].values[0])
            list_rating.append(temp_df[contains_search_string & (temp_df['name'] == item_name)]['rating_star'].values[0])
            arevenue = temp_df[contains_search_string & (temp_df['name'] == item_name)]['sold'].values[0] * \
            temp_df[contains_search_string & (temp_df['name'] == item_name)]['price'].values[0]
            list_arevenue.append(arevenue)

# %%
All_SM_Unique_Word_df = pd.DataFrame({'shop_name': list_shop_name, 'item_name':list_item_name, 'keyword': list_keyword,\
                               'sold': list_sold, 'rating': list_rating, 'approximate revenue': list_arevenue})

# %%
All_SM_Unique_Word_df
# Out:
#              shop_name                                          item_name  \
# 0      Aviano Menswear   Bộ Thể Thao Nam 4 Màu Trẻ Trung Nặng Động VICERO
# 1      Aviano Menswear  Áo Khoác Nam Chất Liệu Cao Cấp Kiểu Dáng Trẻ T...
# 2      Aviano Menswear  Áo Khoác Thể Thao Nam 3 Màu Trẻ Trung Cao Cấp ...
# 3      Aviano Menswear  Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...
# 4      Aviano Menswear  Bộ Thể Thao Nam Chất Nỉ 4 Màu Trẻ Trung Năng Đ...
# ...                ...                                                ...
# 46615            AREMI  Áo thun nam cổ tròn, T-shirt nam đen in AREMI,...
# 46616            AREMI  Áo polo nam thun nam có cổ AREMI chất liệu cá ...
# 46617            AREMI  Áo thun nam tay ngắn cổ tròn AREMI chất liệu c...
# 46618            AREMI  Áo polo nam thun nam tay ngắn có cổ AREMI chất...
# 46619            AREMI  Áo polo nam thun nam có cổ tay ngắn thiết kế A...
#
#         keyword  sold    rating  approximate revenue
# 0           nam    62  4.906764         1.047800e+07
# 1           nam     5  4.848684         6.450000e+05
# 2           nam    84  4.839286         1.083600e+07
# 3           nam  3912  4.847720         7.628400e+08
# 4           nam  6595  4.846812         1.220075e+09
# ...         ...   ...       ...                  ...
# 46615  thun nam     8  4.939759         1.432000e+06
# 46616  thun nam    37  4.870968         7.363000e+06
# 46617  thun nam    28  4.636364         5.012000e+06
# 46618  thun nam    16  5.000000         2.864000e+06
# 46619  thun nam    15  4.000000         2.835000e+06
#
# [46620 rows x 6 columns]

# %%
# All_SM_Unique_Word_df.to_csv('SM_Unique_Word.csv',index=False,header=True,encoding="utf-8-sig")
